# %%
import numpy as np

npz_path = "/home/zhaodanqi/clone/WoTE/ControllerExp/generated/controller_styles.npz"

data = np.load(npz_path, allow_pickle=True)  # allow_pickle=True 防止包含对象类型
print("Keys in npz:", list(data.keys()))
# Out:
# Keys in npz: ['exec_trajs', 'ref_traj', 'style_names', 'lqr_params', 'post_params', 'style_kind', 'style_group_big', 'style_group_sub', 'train_style_indices', 'val_style_indices', 'seed', 'version']

# %%
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# 1️⃣ 载入 npz 文件
npz_path = "/home/zhaodanqi/clone/WoTE/ControllerExp/generated/controller_styles.npz"
data = np.load(npz_path, allow_pickle=True)

# 2️⃣ 指定你想查看的索引
idx_list = [0, 2, 25, 41, 57, 73, 87, 159, 177, 189, 195]

# 3️⃣ 查看每个索引的轨迹和其他信息
for idx in idx_list:
    print(f"\n=== Style idx: {idx} ===")
    
    # 执行轨迹
    # exec_traj = data['exec_trajs'][idx]  # (num_frames, 3) 例如 [x, y, yaw]
    # print(f"exec_trajs shape: {exec_traj.shape}")
    # print(exec_traj[:5])  # 打印前 5 帧示例
    
    # # 参考轨迹
    # ref_traj = data['ref_traj'][idx]
    # print(f"ref_traj shape: {ref_traj.shape}")
    # print(ref_traj[:5])
    
    # 风格名字
    style_name = data['style_names'][idx]
    print(f"style_name: {style_name}")
    
    # 风格类型 / 大小分组 / 子分组
    print(f"style_kind: {data['style_kind'][idx]}")
    print(f"style_group_big: {data['style_group_big'][idx]}")
    print(f"style_group_sub: {data['style_group_sub'][idx]}")
    
    # LQR / 后处理参数
    print(f"lqr_params: {data['lqr_params'][idx]}")
    print(f"post_params: {data['post_params'][idx]}")
# Out:
# === Style idx: 0 ===
# style_name: trk_default_base
# style_kind: trk
# style_group_big: default
# style_group_sub: base
# lqr_params: {'q_longitudinal': [10.0], 'r_longitudinal': [1.0], 'q_lateral': [1.0, 10.0, 0.0], 'r_lateral': [1.0], 'tracking_horizon': 10, 'jerk_penalty': 0.0001, 'curvature_rate_penalty': 0.01}
# post_params: {'style': 'none', 'apply_mode': 'off', 'heading_scale': 1.0, 'heading_bias': 0.0, 'speed_scale': 1.0, 'speed_bias': 0.0, 'noise_std': 0.0}
#
# === Style idx: 2 ===
# style_name: trk_aggressive_mild_01
# style_kind: trk
# style_group_big: aggressive
# style_group_sub: mild
# lqr_params: {'q_longitudinal': [200.0], 'r_longitudinal': [0.01], 'q_lateral': [2.1213380140918505, 112.48435466776274, 1.4247013931549628], 'r_lateral': [0.25638918225943935], 'tracking_horizon': 9, 'jerk_penalty': 9.391671819255927e-05, 'curvature_rate_penalty': 0.005011681487615215}
# ...
